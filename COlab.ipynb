# %% [markdown]
# <a href="https://colab.research.google.com/github/OtterBots/CST383_Project/blob/master/COlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.read_csv("https://github.com/OtterBots/CST383_Project/blob/master/data/AKC_Breed_Info.csv")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-a6ef5f4d9ca5> in <module>
#       1 import pandas as pd
# ----> 2 pd.read_csv("https://github.com/OtterBots/CST383_Project/blob/master/data/AKC_Breed_Info.csv")
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
